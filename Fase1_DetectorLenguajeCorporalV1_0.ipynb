# %%
# 0. Install and import dependencies
# !pip install mediapipe opencv-python pandas scikit-learn
# Out:
# Requirement already satisfied: mediapipe in /Users/cornejos/opt/anaconda3/lib/python3.9/site-packages (0.9.1.0)
# Requirement already satisfied: opencv-python in /Users/cornejos/opt/anaconda3/lib/python3.9/site-packages (4.8.0.76)
# Requirement already satisfied: pandas in /Users/cornejos/opt/anaconda3/lib/python3.9/site-packages (1.3.4)
# Requirement already satisfied: scikit-learn in /Users/cornejos/opt/anaconda3/lib/python3.9/site-packages (0.24.2)
# Requirement already satisfied: absl-py in /Users/cornejos/opt/anaconda3/lib/python3.9/site-packages (from mediapipe) (1.2.0)
# Requirement already satisfied: attrs>=19.1.0 in /Users/cornejos/opt/anaconda3/lib/python3.9/site-packages (from mediapipe) (21.2.0)
# Requirement already satisfied: flatbuffers>=2.0 in /Users/cornejos/opt/anaconda3/lib/python3.9/site-packages (from mediapipe) (23.5.26)
# Requirement already satisfied: matplotlib in /Users/cornejos/opt/anaconda3/lib/python3.9/site-packages (from mediapipe) (3.4.3)
# Requirement already satisfied: numpy in /Users/cornejos/opt/anaconda3/lib/python3.9/site-packages (from mediapipe) (1.22.4)
# Requirement already satisfied: opencv-contrib-python in /Users/cornejos/opt/anaconda3/lib/python3.9/site-packages (from mediapipe) (4.8.0.76)
# Requirement already satisfied: protobuf<4,>=3.11 in /Users/cornejos/opt/anaconda3/lib/python3.9/site-packages (from mediapipe) (3.20.3)
# Requirement already satisfied: python-dateutil>=2.7.3 in /Users/cornejos/opt/anaconda3/lib/python3.9/site-packages (from pandas) (2.8.2)
# Requirement already satisfied: pytz>=2017.3 in /Users/cornejos/opt/anaconda3/lib/python3.9/site-packages (from pandas) (2021.3)
# Requirement already satisfied: scipy>=0.19.1 in /Users/cornejos/opt/anaconda3/lib/python3.9/site-packages (from scikit-learn) (1.7.1)
# Requirement already satisfied: joblib>=0.11 in /Users/cornejos/opt/anaconda3/lib/python3.9/site-packages (from scikit-learn) (1.1.0)
# Requirement already satisfied: threadpoolctl>=2.0.0 in /Users/cornejos/opt/anaconda3/lib/python3.9/site-packages (from scikit-learn) (2.2.0)
# Requirement already satisfied: six>=1.5 in /Users/cornejos/opt/anaconda3/lib/python3.9/site-packages (from python-dateutil>=2.7.3->pandas) (1.16.0)
# Requirement already satisfied: cycler>=0.10 in /Users/cornejos/opt/anaconda3/lib/python3.9/site-packages (from matplotlib->mediapipe) (0.10.0)
# Requirement already satisfied: kiwisolver>=1.0.1 in /Users/cornejos/opt/anaconda3/lib/python3.9/site-packages (from matplotlib->mediapipe) (1.3.1)
# Requirement already satisfied: pillow>=6.2.0 in /Users/cornejos/opt/anaconda3/lib/python3.9/site-packages (from matplotlib->mediapipe) (8.4.0)
# Requirement already satisfied: pyparsing>=2.2.1 in /Users/cornejos/opt/anaconda3/lib/python3.9/site-packages (from matplotlib->mediapipe) (3.0.4)
# DEPRECATION: pyodbc 4.0.0-unsupported has a non-standard version number. pip 23.3 will enforce this behaviour change. A possible replacement is to upgrade to a newer version of pyodbc or contact the author to suggest that they release a version with a conforming version number. Discussion can be found at https://github.com/pypa/pip/issues/12063

# %%
import mediapipe as mp # Import mediapipe
import cv2 # Import opencv
# Out:
# 2023-10-08 20:42:57.351679: I tensorflow/core/platform/cpu_feature_guard.cc:182] This TensorFlow binary is optimized to use available CPU instructions in performance-critical operations.
# To enable the following instructions: AVX2 FMA, in other operations, rebuild TensorFlow with the appropriate compiler flags.

# %%
len(results.pose_landmarks.landmark)+len(results.face_landmarks.landmark)
num_coords
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# /var/folders/s9/qmh4_pw14t51mdl6skzn4xpr0000gn/T/ipykernel_27480/7126313.py in <module>
# ----> 1 len(results.pose_landmarks.landmark)+len(results.face_landmarks.landmark)
#       2 num_coords
#
# NameError: name 'results' is not defined

# %%
mp_drawing = mp.solutions.drawing_utils # Drawing helpers
mp_holistic = mp.solutions.holistic # Mediapipe solutions

# %%
# 1. Make Some Detections
cap = cv2.VideoCapture(0)
# Initiate holistic model
with mp_holistic.Holistic(min_detection_confidence=0.5, min_tracking_confidence=0.5) as holistic:
    
    while cap.isOpened():
        ret, frame = cap.read()
        
        # Recolor Feed
        image = cv2.cvtColor(frame, cv2.COLOR_BGR2RGB)
        image.flags.writeable = False        
        
        # Make Detections
        results = holistic.process(image)
        # print(results.face_landmarks)
        
        # face_landmarks, pose_landmarks, left_hand_landmarks, right_hand_landmarks
        
        # Recolor image back to BGR for rendering
        image.flags.writeable = True   
        image = cv2.cvtColor(image, cv2.COLOR_RGB2BGR)
        
        # 1. Draw face landmarks
        mp_drawing.draw_landmarks(image, results.face_landmarks, mp_holistic.FACEMESH_TESSELATION, 
                                 mp_drawing.DrawingSpec(color=(80,110,10), thickness=1, circle_radius=1),
                                 mp_drawing.DrawingSpec(color=(80,256,121), thickness=1, circle_radius=1)
                                 )
        
        # 2. Right hand
        mp_drawing.draw_landmarks(image, results.right_hand_landmarks, mp_holistic.HAND_CONNECTIONS, 
                                 mp_drawing.DrawingSpec(color=(80,22,10), thickness=2, circle_radius=4),
                                 mp_drawing.DrawingSpec(color=(80,44,121), thickness=2, circle_radius=2)
                                 )

        # 3. Left Hand
        mp_drawing.draw_landmarks(image, results.left_hand_landmarks, mp_holistic.HAND_CONNECTIONS, 
                                 mp_drawing.DrawingSpec(color=(121,22,76), thickness=2, circle_radius=4),
                                 mp_drawing.DrawingSpec(color=(121,44,250), thickness=2, circle_radius=2)
                                 )

        # 4. Pose Detections
        mp_drawing.draw_landmarks(image, results.pose_landmarks, mp_holistic.POSE_CONNECTIONS, 
                                 mp_drawing.DrawingSpec(color=(245,117,66), thickness=2, circle_radius=4),
                                 mp_drawing.DrawingSpec(color=(245,66,230), thickness=2, circle_radius=2)
                                 )
                        
        cv2.imshow('Raw Webcam Feed', image)

        if cv2.waitKey(10) & 0xFF == ord('q'):
            break

cap.release()
cv2.destroyAllWindows()
# Out:
# 2023-10-08 20:43:34.738 python[27480:2154778] WARNING: AVCaptureDeviceTypeExternal is deprecated for Continuity Cameras. Please use AVCaptureDeviceTypeContinuityCamera and add NSCameraUseContinuityCameraDeviceType to your Info.plist.
# INFO: Created TensorFlow Lite XNNPACK delegate for CPU.

# %%
results.face_landmarks.landmark[0].visibility

# %%
# 2. Capture Landmarks & Export to CSV
import csv
import os
import numpy as np

# %%
num_coords = len(results.pose_landmarks.landmark)+len(results.face_landmarks.landmark)
num_coords
# Out:
# 501

# %%
landmarks = ['class']
for val in range(1, num_coords+1):
    landmarks += ['x{}'.format(val), 'y{}'.format(val), 'z{}'.format(val), 'v{}'.format(val)]

# %%
landmarks
# Out:
# ['class',
#  'x1',
#  'y1',
#  'z1',
#  'v1',
#  'x2',
#  'y2',
#  'z2',
#  'v2',
#  'x3',
#  'y3',
#  'z3',
#  'v3',
#  'x4',
#  'y4',
#  'z4',
#  'v4',
#  'x5',
#  'y5',
#  'z5',
#  'v5',
#  'x6',
#  'y6',
#  'z6',
#  'v6',
#  'x7',
#  'y7',
#  'z7',
#  'v7',
#  'x8',
#  'y8',
#  'z8',
#  'v8',
#  'x9',
#  'y9',
#  'z9',
#  'v9',
#  'x10',
#  'y10',
#  'z10',
#  'v10',
#  'x11',
#  'y11',
#  'z11',
#  'v11',
#  'x12',
#  'y12',
#  'z12',
#  'v12',
#  'x13',
#  'y13',
#  'z13',
#  'v13',
#  'x14',
#  'y14',
#  'z14',
#  'v14',
#  'x15',
#  'y15',
#  'z15',
#  'v15',
#  'x16',
#  'y16',
#  'z16',
#  'v16',
#  'x17',
#  'y17',
#  'z17',
#  'v17',
#  'x18',
#  'y18',
#  'z18',
#  'v18',
#  'x19',
#  'y19',
#  'z19',
#  'v19',
#  'x20',
#  'y20',
#  'z20',
#  'v20',
#  'x21',
#  'y21',
#  'z21',
#  'v21',
#  'x22',
#  'y22',
#  'z22',
#  'v22',
#  'x23',
#  'y23',
#  'z23',
#  'v23',
#  'x24',
#  'y24',
#  'z24',
#  'v24',
#  'x25',
#  'y25',
#  'z25',
#  'v25',
#  'x26',
#  'y26',
#  'z26',
#  'v26',
#  'x27',
#  'y27',
#  'z27',
#  'v27',
#  'x28',
#  'y28',
#  'z28',
#  'v28',
#  'x29',
#  'y29',
#  'z29',
#  'v29',
#  'x30',
#  'y30',
#  'z30',
#  'v30',
#  'x31',
#  'y31',
#  'z31',
#  'v31',
#  'x32',
#  'y32',
#  'z32',
#  'v32',
#  'x33',
#  'y33',
#  'z33',
#  'v33',
#  'x34',
#  'y34',
#  'z34',
#  'v34',
#  'x35',
#  'y35',
#  'z35',
#  'v35',
#  'x36',
#  'y36',
#  'z36',
#  'v36',
#  'x37',
#  'y37',
#  'z37',
#  'v37',
#  'x38',
#  'y38',
#  'z38',
#  'v38',
#  'x39',
#  'y39',
#  'z39',
#  'v39',
#  'x40',
#  'y40',
#  'z40',
#  'v40',
#  'x41',
#  'y41',
#  'z41',
#  'v41',
#  'x42',
#  'y42',
#  'z42',
#  'v42',
#  'x43',
#  'y43',
#  'z43',
#  'v43',
#  'x44',
#  'y44',
#  'z44',
#  'v44',
#  'x45',
#  'y45',
#  'z45',
#  'v45',
#  'x46',
#  'y46',
#  'z46',
#  'v46',
#  'x47',
#  'y47',
#  'z47',
#  'v47',
#  'x48',
#  'y48',
#  'z48',
#  'v48',
#  'x49',
#  'y49',
#  'z49',
#  'v49',
#  'x50',
#  'y50',
#  'z50',
#  'v50',
#  'x51',
#  'y51',
#  'z51',
#  'v51',
#  'x52',
#  'y52',
#  'z52',
#  'v52',
#  'x53',
#  'y53',
#  'z53',
#  'v53',
#  'x54',
#  'y54',
#  'z54',
#  'v54',
#  'x55',
#  'y55',
#  'z55',
#  'v55',
#  'x56',
#  'y56',
#  'z56',
#  'v56',
#  'x57',
#  'y57',
#  'z57',
#  'v57',
#  'x58',
#  'y58',
#  'z58',
#  'v58',
#  'x59',
#  'y59',
#  'z59',
#  'v59',
#  'x60',
#  'y60',
#  'z60',
#  'v60',
#  'x61',
#  'y61',
#  'z61',
#  'v61',
#  'x62',
#  'y62',
#  'z62',
#  'v62',
#  'x63',
#  'y63',
#  'z63',
#  'v63',
#  'x64',
#  'y64',
#  'z64',
#  'v64',
#  'x65',
#  'y65',
#  'z65',
#  'v65',
#  'x66',
#  'y66',
#  'z66',
#  'v66',
#  'x67',
#  'y67',
#  'z67',
#  'v67',
#  'x68',
#  'y68',
#  'z68',
#  'v68',
#  'x69',
#  'y69',
#  'z69',
#  'v69',
#  'x70',
#  'y70',
#  'z70',
#  'v70',
#  'x71',
#  'y71',
#  'z71',
#  'v71',
#  'x72',
#  'y72',
#  'z72',
#  'v72',
#  'x73',
#  'y73',
#  'z73',
#  'v73',
#  'x74',
#  'y74',
#  'z74',
#  'v74',
#  'x75',
#  'y75',
#  'z75',
#  'v75',
#  'x76',
#  'y76',
#  'z76',
#  'v76',
#  'x77',
#  'y77',
#  'z77',
#  'v77',
#  'x78',
#  'y78',
#  'z78',
#  'v78',
#  'x79',
#  'y79',
#  'z79',
#  'v79',
#  'x80',
#  'y80',
#  'z80',
#  'v80',
#  'x81',
#  'y81',
#  'z81',
#  'v81',
#  'x82',
#  'y82',
#  'z82',
#  'v82',
#  'x83',
#  'y83',
#  'z83',
#  'v83',
#  'x84',
#  'y84',
#  'z84',
#  'v84',
#  'x85',
#  'y85',
#  'z85',
#  'v85',
#  'x86',
#  'y86',
#  'z86',
#  'v86',
#  'x87',
#  'y87',
#  'z87',
#  'v87',
#  'x88',
#  'y88',
#  'z88',
#  'v88',
#  'x89',
#  'y89',
#  'z89',
#  'v89',
#  'x90',
#  'y90',
#  'z90',
#  'v90',
#  'x91',
#  'y91',
#  'z91',
#  'v91',
#  'x92',
#  'y92',
#  'z92',
#  'v92',
#  'x93',
#  'y93',
#  'z93',
#  'v93',
#  'x94',
#  'y94',
#  'z94',
#  'v94',
#  'x95',
#  'y95',
#  'z95',
#  'v95',
#  'x96',
#  'y96',
#  'z96',
#  'v96',
#  'x97',
#  'y97',
#  'z97',
#  'v97',
#  'x98',
#  'y98',
#  'z98',
#  'v98',
#  'x99',
#  'y99',
#  'z99',
#  'v99',
#  'x100',
#  'y100',
#  'z100',
#  'v100',
#  'x101',
#  'y101',
#  'z101',
#  'v101',
#  'x102',
#  'y102',
#  'z102',
#  'v102',
#  'x103',
#  'y103',
#  'z103',
#  'v103',
#  'x104',
#  'y104',
#  'z104',
#  'v104',
#  'x105',
#  'y105',
#  'z105',
#  'v105',
#  'x106',
#  'y106',
#  'z106',
#  'v106',
#  'x107',
#  'y107',
#  'z107',
#  'v107',
#  'x108',
#  'y108',
#  'z108',
#  'v108',
#  'x109',
#  'y109',
#  'z109',
#  'v109',
#  'x110',
#  'y110',
#  'z110',
#  'v110',
#  'x111',
#  'y111',
#  'z111',
#  'v111',
#  'x112',
#  'y112',
#  'z112',
#  'v112',
#  'x113',
#  'y113',
#  'z113',
#  'v113',
#  'x114',
#  'y114',
#  'z114',
#  'v114',
#  'x115',
#  'y115',
#  'z115',
#  'v115',
#  'x116',
#  'y116',
#  'z116',
#  'v116',
#  'x117',
#  'y117',
#  'z117',
#  'v117',
#  'x118',
#  'y118',
#  'z118',
#  'v118',
#  'x119',
#  'y119',
#  'z119',
#  'v119',
#  'x120',
#  'y120',
#  'z120',
#  'v120',
#  'x121',
#  'y121',
#  'z121',
#  'v121',
#  'x122',
#  'y122',
#  'z122',
#  'v122',
#  'x123',
#  'y123',
#  'z123',
#  'v123',
#  'x124',
#  'y124',
#  'z124',
#  'v124',
#  'x125',
#  'y125',
#  'z125',
#  'v125',
#  'x126',
#  'y126',
#  'z126',
#  'v126',
#  'x127',
#  'y127',
#  'z127',
#  'v127',
#  'x128',
#  'y128',
#  'z128',
#  'v128',
#  'x129',
#  'y129',
#  'z129',
#  'v129',
#  'x130',
#  'y130',
#  'z130',
#  'v130',
#  'x131',
#  'y131',
#  'z131',
#  'v131',
#  'x132',
#  'y132',
#  'z132',
#  'v132',
#  'x133',
#  'y133',
#  'z133',
#  'v133',
#  'x134',
#  'y134',
#  'z134',
#  'v134',
#  'x135',
#  'y135',
#  'z135',
#  'v135',
#  'x136',
#  'y136',
#  'z136',
#  'v136',
#  'x137',
#  'y137',
#  'z137',
#  'v137',
#  'x138',
#  'y138',
#  'z138',
#  'v138',
#  'x139',
#  'y139',
#  'z139',
#  'v139',
#  'x140',
#  'y140',
#  'z140',
#  'v140',
#  'x141',
#  'y141',
#  'z141',
#  'v141',
#  'x142',
#  'y142',
#  'z142',
#  'v142',
#  'x143',
#  'y143',
#  'z143',
#  'v143',
#  'x144',
#  'y144',
#  'z144',
#  'v144',
#  'x145',
#  'y145',
#  'z145',
#  'v145',
#  'x146',
#  'y146',
#  'z146',
#  'v146',
#  'x147',
#  'y147',
#  'z147',
#  'v147',
#  'x148',
#  'y148',
#  'z148',
#  'v148',
#  'x149',
#  'y149',
#  'z149',
#  'v149',
#  'x150',
#  'y150',
#  'z150',
#  'v150',
#  'x151',
#  'y151',
#  'z151',
#  'v151',
#  'x152',
#  'y152',
#  'z152',
#  'v152',
#  'x153',
#  'y153',
#  'z153',
#  'v153',
#  'x154',
#  'y154',
#  'z154',
#  'v154',
#  'x155',
#  'y155',
#  'z155',
#  'v155',
#  'x156',
#  'y156',
#  'z156',
#  'v156',
#  'x157',
#  'y157',
#  'z157',
#  'v157',
#  'x158',
#  'y158',
#  'z158',
#  'v158',
#  'x159',
#  'y159',
#  'z159',
#  'v159',
#  'x160',
#  'y160',
#  'z160',
#  'v160',
#  'x161',
#  'y161',
#  'z161',
#  'v161',
#  'x162',
#  'y162',
#  'z162',
#  'v162',
#  'x163',
#  'y163',
#  'z163',
#  'v163',
#  'x164',
#  'y164',
#  'z164',
#  'v164',
#  'x165',
#  'y165',
#  'z165',
#  'v165',
#  'x166',
#  'y166',
#  'z166',
#  'v166',
#  'x167',
#  'y167',
#  'z167',
#  'v167',
#  'x168',
#  'y168',
#  'z168',
#  'v168',
#  'x169',
#  'y169',
#  'z169',
#  'v169',
#  'x170',
#  'y170',
#  'z170',
#  'v170',
#  'x171',
#  'y171',
#  'z171',
#  'v171',
#  'x172',
#  'y172',
#  'z172',
#  'v172',
#  'x173',
#  'y173',
#  'z173',
#  'v173',
#  'x174',
#  'y174',
#  'z174',
#  'v174',
#  'x175',
#  'y175',
#  'z175',
#  'v175',
#  'x176',
#  'y176',
#  'z176',
#  'v176',
#  'x177',
#  'y177',
#  'z177',
#  'v177',
#  'x178',
#  'y178',
#  'z178',
#  'v178',
#  'x179',
#  'y179',
#  'z179',
#  'v179',
#  'x180',
#  'y180',
#  'z180',
#  'v180',
#  'x181',
#  'y181',
#  'z181',
#  'v181',
#  'x182',
#  'y182',
#  'z182',
#  'v182',
#  'x183',
#  'y183',
#  'z183',
#  'v183',
#  'x184',
#  'y184',
#  'z184',
#  'v184',
#  'x185',
#  'y185',
#  'z185',
#  'v185',
#  'x186',
#  'y186',
#  'z186',
#  'v186',
#  'x187',
#  'y187',
#  'z187',
#  'v187',
#  'x188',
#  'y188',
#  'z188',
#  'v188',
#  'x189',
#  'y189',
#  'z189',
#  'v189',
#  'x190',
#  'y190',
#  'z190',
#  'v190',
#  'x191',
#  'y191',
#  'z191',
#  'v191',
#  'x192',
#  'y192',
#  'z192',
#  'v192',
#  'x193',
#  'y193',
#  'z193',
#  'v193',
#  'x194',
#  'y194',
#  'z194',
#  'v194',
#  'x195',
#  'y195',
#  'z195',
#  'v195',
#  'x196',
#  'y196',
#  'z196',
#  'v196',
#  'x197',
#  'y197',
#  'z197',
#  'v197',
#  'x198',
#  'y198',
#  'z198',
#  'v198',
#  'x199',
#  'y199',
#  'z199',
#  'v199',
#  'x200',
#  'y200',
#  'z200',
#  'v200',
#  'x201',
#  'y201',
#  'z201',
#  'v201',
#  'x202',
#  'y202',
#  'z202',
#  'v202',
#  'x203',
#  'y203',
#  'z203',
#  'v203',
#  'x204',
#  'y204',
#  'z204',
#  'v204',
#  'x205',
#  'y205',
#  'z205',
#  'v205',
#  'x206',
#  'y206',
#  'z206',
#  'v206',
#  'x207',
#  'y207',
#  'z207',
#  'v207',
#  'x208',
#  'y208',
#  'z208',
#  'v208',
#  'x209',
#  'y209',
#  'z209',
#  'v209',
#  'x210',
#  'y210',
#  'z210',
#  'v210',
#  'x211',
#  'y211',
#  'z211',
#  'v211',
#  'x212',
#  'y212',
#  'z212',
#  'v212',
#  'x213',
#  'y213',
#  'z213',
#  'v213',
#  'x214',
#  'y214',
#  'z214',
#  'v214',
#  'x215',
#  'y215',
#  'z215',
#  'v215',
#  'x216',
#  'y216',
#  'z216',
#  'v216',
#  'x217',
#  'y217',
#  'z217',
#  'v217',
#  'x218',
#  'y218',
#  'z218',
#  'v218',
#  'x219',
#  'y219',
#  'z219',
#  'v219',
#  'x220',
#  'y220',
#  'z220',
#  'v220',
#  'x221',
#  'y221',
#  'z221',
#  'v221',
#  'x222',
#  'y222',
#  'z222',
#  'v222',
#  'x223',
#  'y223',
#  'z223',
#  'v223',
#  'x224',
#  'y224',
#  'z224',
#  'v224',
#  'x225',
#  'y225',
#  'z225',
#  'v225',
#  'x226',
#  'y226',
#  'z226',
#  'v226',
#  'x227',
#  'y227',
#  'z227',
#  'v227',
#  'x228',
#  'y228',
#  'z228',
#  'v228',
#  'x229',
#  'y229',
#  'z229',
#  'v229',
#  'x230',
#  'y230',
#  'z230',
#  'v230',
#  'x231',
#  'y231',
#  'z231',
#  'v231',
#  'x232',
#  'y232',
#  'z232',
#  'v232',
#  'x233',
#  'y233',
#  'z233',
#  'v233',
#  'x234',
#  'y234',
#  'z234',
#  'v234',
#  'x235',
#  'y235',
#  'z235',
#  'v235',
#  'x236',
#  'y236',
#  'z236',
#  'v236',
#  'x237',
#  'y237',
#  'z237',
#  'v237',
#  'x238',
#  'y238',
#  'z238',
#  'v238',
#  'x239',
#  'y239',
#  'z239',
#  'v239',
#  'x240',
#  'y240',
#  'z240',
#  'v240',
#  'x241',
#  'y241',
#  'z241',
#  'v241',
#  'x242',
#  'y242',
#  'z242',
#  'v242',
#  'x243',
#  'y243',
#  'z243',
#  'v243',
#  'x244',
#  'y244',
#  'z244',
#  'v244',
#  'x245',
#  'y245',
#  'z245',
#  'v245',
#  'x246',
#  'y246',
#  'z246',
#  'v246',
#  'x247',
#  'y247',
#  'z247',
#  'v247',
#  'x248',
#  'y248',
#  'z248',
#  'v248',
#  'x249',
#  'y249',
#  'z249',
#  'v249',
#  'x250',
#  'y250',
#  'z250',
#  ...]

# %%
with open('coords.csv', mode='w', newline='') as f:
    csv_writer = csv.writer(f, delimiter=',', quotechar='"', quoting=csv.QUOTE_MINIMAL)
    csv_writer.writerow(landmarks)

# %%
class_name = "PulgaresAfuera"

# %%
cap = cv2.VideoCapture(0)
# Initiate holistic model
with mp_holistic.Holistic(min_detection_confidence=0.5, min_tracking_confidence=0.5) as holistic:
    
    while cap.isOpened():
        ret, frame = cap.read()
        
        # Recolor Feed
        image = cv2.cvtColor(frame, cv2.COLOR_BGR2RGB)
        image.flags.writeable = False        
        
        # Make Detections
        results = holistic.process(image)
        # print(results.face_landmarks)
        
        # face_landmarks, pose_landmarks, left_hand_landmarks, right_hand_landmarks
        
        # Recolor image back to BGR for rendering
        image.flags.writeable = True   
        image = cv2.cvtColor(image, cv2.COLOR_RGB2BGR)
        
        # 1. Draw face landmarks
        mp_drawing.draw_landmarks(image, results.face_landmarks, mp_holistic.FACEMESH_TESSELATION, 
                                 mp_drawing.DrawingSpec(color=(80,110,10), thickness=1, circle_radius=1),
                                 mp_drawing.DrawingSpec(color=(80,256,121), thickness=1, circle_radius=1)
                                 )
        
        # 2. Right hand
        mp_drawing.draw_landmarks(image, results.right_hand_landmarks, mp_holistic.HAND_CONNECTIONS, 
                                 mp_drawing.DrawingSpec(color=(80,22,10), thickness=2, circle_radius=4),
                                 mp_drawing.DrawingSpec(color=(80,44,121), thickness=2, circle_radius=2)
                                 )

        # 3. Left Hand
        mp_drawing.draw_landmarks(image, results.left_hand_landmarks, mp_holistic.HAND_CONNECTIONS, 
                                 mp_drawing.DrawingSpec(color=(121,22,76), thickness=2, circle_radius=4),
                                 mp_drawing.DrawingSpec(color=(121,44,250), thickness=2, circle_radius=2)
                                 )

        # 4. Pose Detections
        mp_drawing.draw_landmarks(image, results.pose_landmarks, mp_holistic.POSE_CONNECTIONS, 
                                 mp_drawing.DrawingSpec(color=(245,117,66), thickness=2, circle_radius=4),
                                 mp_drawing.DrawingSpec(color=(245,66,230), thickness=2, circle_radius=2)
                                 )
        # Export coordinates
        try:
            # Extract Pose landmarks
            pose = results.pose_landmarks.landmark
            pose_row = list(np.array([[landmark.x, landmark.y, landmark.z, landmark.visibility] for landmark in pose]).flatten())
            
            # Extract Face landmarks
            face = results.face_landmarks.landmark
            face_row = list(np.array([[landmark.x, landmark.y, landmark.z, landmark.visibility] for landmark in face]).flatten())
            
            # Concate rows
            row = pose_row+face_row
            
            # Append class name 
            row.insert(0, class_name)
            
            # Export to CSV
            with open('coords.csv', mode='a', newline='') as f:
                csv_writer = csv.writer(f, delimiter=',', quotechar='"', quoting=csv.QUOTE_MINIMAL)
                csv_writer.writerow(row) 
            
        except:
            pass
                        
        cv2.imshow('Raw Webcam Feed', image)

        if cv2.waitKey(10) & 0xFF == ord('q'):
            break

cap.release()
cv2.destroyAllWindows()

# %%
# 3. Train Custom Model Using Scikit Learn
# 3.1 Read in Collected Data and Process
import pandas as pd
from sklearn.model_selection import train_test_split

# %%
df = pd.read_csv('coords.csv')

# %%
df.head()
# Out:
#          class        x1        y1        z1        v1        x2        y2  \
# 0  ManoAbierta  0.518986  0.417074 -0.762488  0.999979  0.541851  0.368942
# 1  ManoAbierta  0.518304  0.419207 -1.016083  0.999978  0.540666  0.370528
# 2  ManoAbierta  0.518103  0.422219 -1.060706  0.999977  0.540102  0.371352
# 3  ManoAbierta  0.518086  0.425534 -1.063431  0.999977  0.540006  0.372480
# 4  ManoAbierta  0.516708  0.430625 -1.034972  0.999975  0.539038  0.376430
#
#          z2        v2        x3  ...      z499  v499      x500      y500  \
# 0 -0.720089  0.999937  0.557240  ...  0.016913     0  0.585184  0.377106
# 1 -0.952385  0.999934  0.556544  ...  0.015096     0  0.586466  0.377904
# 2 -0.998287  0.999932  0.556206  ...  0.014158     0  0.586534  0.379752
# 3 -1.002027  0.999931  0.556174  ...  0.013231     0  0.585414  0.378490
# 4 -0.974638  0.999924  0.555343  ...  0.013983     0  0.584289  0.382605
#
#        z500  v500      x501      y501      z501  v501
# 0  0.041725     0  0.589401  0.371056  0.043289     0
# 1  0.038115     0  0.591152  0.371479  0.039521     0
# 2  0.037448     0  0.591332  0.373329  0.038823     0
# 3  0.036124     0  0.590307  0.371653  0.037448     0
# 4  0.037347     0  0.588843  0.376351  0.038749     0
#
# [5 rows x 2005 columns]

# %%
df.tail()
# Out:
#               class        x1        y1        z1        v1        x2  \
# 500  PulgaresAfuera  0.509245  0.083171 -0.163531  0.999806  0.522582
# 501  PulgaresAfuera  0.508540  0.081689 -0.167902  0.999821  0.521751
# 502  PulgaresAfuera  0.505134  0.080085 -0.171397  0.999811  0.518966
# 503  PulgaresAfuera  0.510024  0.058018 -0.233239  0.999818  0.525092
# 504  PulgaresAfuera  0.525338  0.032173 -0.235840  0.999829  0.540302
#
#            y2        z2        v2        x3  ...      z499  v499      x500  \
# 500  0.047773 -0.156678  0.999668  0.531739  ...  0.002737     0  0.542659
# 501  0.046770 -0.158009  0.999692  0.531199  ...  0.002287     0  0.541089
# 502  0.045694 -0.158357  0.999675  0.528546  ...  0.002920     0  0.538103
# 503  0.027144 -0.219893  0.999684  0.535045  ...  0.004447     0  0.552380
# 504  0.003319 -0.227210  0.999698  0.549748  ...  0.006227     0  0.565565
#
#          y500      z500  v500      x501      y501      z501  v501
# 500  0.043846  0.007530     0  0.545112  0.040203  0.007655     0
# 501  0.039909  0.007251     0  0.543460  0.036318  0.007358     0
# 502  0.027259  0.008398     0  0.540413  0.023704  0.008551     0
# 503  0.009287  0.011455     0  0.554871  0.004571  0.011816     0
# 504 -0.004879  0.013192     0  0.568037 -0.011048  0.013649     0
#
# [5 rows x 2005 columns]

# %%
df[df['class']=='ManoAbierta']
# Out:
#            class        x1        y1        z1        v1        x2        y2  \
# 0    ManoAbierta  0.518986  0.417074 -0.762488  0.999979  0.541851  0.368942
# 1    ManoAbierta  0.518304  0.419207 -1.016083  0.999978  0.540666  0.370528
# 2    ManoAbierta  0.518103  0.422219 -1.060706  0.999977  0.540102  0.371352
# 3    ManoAbierta  0.518086  0.425534 -1.063431  0.999977  0.540006  0.372480
# 4    ManoAbierta  0.516708  0.430625 -1.034972  0.999975  0.539038  0.376430
# ..           ...       ...       ...       ...       ...       ...       ...
# 139  ManoAbierta  0.491586  0.463292 -0.988191  0.999974  0.511424  0.401938
# 140  ManoAbierta  0.492455  0.475615 -0.994895  0.999974  0.513210  0.407792
# 141  ManoAbierta  0.492611  0.475397 -1.036364  0.999974  0.513364  0.407539
# 142  ManoAbierta  0.491421  0.475220 -1.019230  0.999974  0.512972  0.407541
# 143  ManoAbierta  0.491363  0.474813 -1.027031  0.999974  0.512835  0.407524
#
#            z2        v2        x3  ...      z499  v499      x500      y500  \
# 0   -0.720089  0.999937  0.557240  ...  0.016913     0  0.585184  0.377106
# 1   -0.952385  0.999934  0.556544  ...  0.015096     0  0.586466  0.377904
# 2   -0.998287  0.999932  0.556206  ...  0.014158     0  0.586534  0.379752
# 3   -1.002027  0.999931  0.556174  ...  0.013231     0  0.585414  0.378490
# 4   -0.974638  0.999924  0.555343  ...  0.013983     0  0.584289  0.382605
# ..        ...       ...       ...  ...       ...   ...       ...       ...
# 139 -0.932544  0.999925  0.526632  ...  0.004324     0  0.561484  0.439778
# 140 -0.941261  0.999927  0.528340  ...  0.003460     0  0.564195  0.443547
# 141 -0.980683  0.999925  0.528664  ...  0.005463     0  0.561511  0.436629
# 142 -0.965015  0.999927  0.528563  ...  0.008122     0  0.558693  0.421706
# 143 -0.972526  0.999926  0.528441  ...  0.007698     0  0.554965  0.406991
#
#          z500  v500      x501      y501      z501  v501
# 0    0.041725     0  0.589401  0.371056  0.043289     0
# 1    0.038115     0  0.591152  0.371479  0.039521     0
# 2    0.037448     0  0.591332  0.373329  0.038823     0
# 3    0.036124     0  0.590307  0.371653  0.037448     0
# 4    0.037347     0  0.588843  0.376351  0.038749     0
# ..        ...   ...       ...       ...       ...   ...
# 139  0.027504     0  0.565815  0.433389  0.028716     0
# 140  0.026942     0  0.568322  0.437276  0.028113     0
# 141  0.027495     0  0.565940  0.430288  0.028630     0
# 142  0.030326     0  0.563055  0.414524  0.031617     0
# 143  0.029900     0  0.558982  0.401338  0.031013     0
#
# [144 rows x 2005 columns]

# %%
X = df.drop('class', axis=1) # features
y = df['class'] # target value

# %%
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.3, random_state=1234)

# %%
y_test
# Out:
# 64         ManoAbierta
# 401     PulgaresAfuera
# 479     PulgaresAfuera
# 124        ManoAbierta
# 131        ManoAbierta
#             ...
# 323    DocumentosALado
# 194    DocumentosALado
# 108        ManoAbierta
# 312    DocumentosALado
# 99         ManoAbierta
# Name: class, Length: 152, dtype: object

# %%
# 3.2 Train Machine Learning Classification Model
from sklearn.pipeline import make_pipeline 
from sklearn.preprocessing import StandardScaler 
from sklearn.linear_model import LogisticRegression, RidgeClassifier
from sklearn.ensemble import RandomForestClassifier, GradientBoostingClassifier

# %%
pipelines = {
    'lr':make_pipeline(StandardScaler(), LogisticRegression()),
    'rc':make_pipeline(StandardScaler(), RidgeClassifier()),
    'rf':make_pipeline(StandardScaler(), RandomForestClassifier()),
    'gb':make_pipeline(StandardScaler(), GradientBoostingClassifier()),
}

# %%
fit_models = {}
for algo, pipeline in pipelines.items():
    model = pipeline.fit(X_train, y_train)
    fit_models[algo] = model
fit_models
fit_models['rc'].predict(X_test)
# Out:
# /Users/cornejos/opt/anaconda3/lib/python3.9/site-packages/sklearn/linear_model/_logistic.py:763: ConvergenceWarning: lbfgs failed to converge (status=1):
# STOP: TOTAL NO. of ITERATIONS REACHED LIMIT.
#
# Increase the number of iterations (max_iter) or scale the data as shown in:
#     https://scikit-learn.org/stable/modules/preprocessing.html
# Please also refer to the documentation for alternative solver options:
#     https://scikit-learn.org/stable/modules/linear_model.html#logistic-regression
#   n_iter_i = _check_optimize_result(
# array(['ManoAbierta', 'PulgaresAfuera', 'PulgaresAfuera', 'ManoAbierta',
#        'ManoAbierta', 'DocumentosALado', 'DocumentosALado',
#        'DocumentosALado', 'ManoAbierta', 'DocumentosALado',
#        'PulgaresAfuera', 'ManoAbierta', 'PulgaresAfuera', 'ManoAbierta',
#        'PulgaresAfuera', 'ManoAbierta', 'DocumentosALado', 'ManoAbierta',
#        'ManoAbierta', 'DocumentosALado', 'DocumentosALado', 'ManoAbierta',
#        'PulgaresAfuera', 'ManoAbierta', 'DocumentosALado', 'ManoAbierta',
#        'ManoAbierta', 'DocumentosALado', 'PulgaresAfuera',
#        'DocumentosALado', 'ManoAbierta', 'ManoAbierta', 'DocumentosALado',
#        'PulgaresAfuera', 'DocumentosALado', 'PulgaresAfuera',
#        'DocumentosALado', 'DocumentosALado', 'PulgaresAfuera',
#        'PulgaresAfuera', 'PulgaresAfuera', 'ManoAbierta',
#        'DocumentosALado', 'DocumentosALado', 'PulgaresAfuera',
#        'DocumentosALado', 'PulgaresAfuera', 'DocumentosALado',
#        'ManoAbierta', 'DocumentosALado', 'DocumentosALado',
#        'DocumentosALado', 'DocumentosALado', 'DocumentosALado',
#        'PulgaresAfuera', 'ManoAbierta', 'DocumentosALado',
#        'DocumentosALado', 'ManoAbierta', 'PulgaresAfuera', 'ManoAbierta',
#        'DocumentosALado', 'DocumentosALado', 'DocumentosALado',
#        'ManoAbierta', 'DocumentosALado', 'DocumentosALado',
#        'PulgaresAfuera', 'DocumentosALado', 'ManoAbierta',
#        'DocumentosALado', 'PulgaresAfuera', 'DocumentosALado',
#        'ManoAbierta', 'PulgaresAfuera', 'DocumentosALado',
#        'DocumentosALado', 'ManoAbierta', 'DocumentosALado',
#        'DocumentosALado', 'DocumentosALado', 'ManoAbierta',
#        'DocumentosALado', 'PulgaresAfuera', 'DocumentosALado',
#        'DocumentosALado', 'ManoAbierta', 'ManoAbierta', 'ManoAbierta',
#        'ManoAbierta', 'DocumentosALado', 'ManoAbierta', 'DocumentosALado',
#        'DocumentosALado', 'DocumentosALado', 'DocumentosALado',
#        'DocumentosALado', 'DocumentosALado', 'DocumentosALado',
#        'DocumentosALado', 'DocumentosALado', 'DocumentosALado',
#        'PulgaresAfuera', 'PulgaresAfuera', 'PulgaresAfuera',
#        'DocumentosALado', 'DocumentosALado', 'DocumentosALado',
#        'PulgaresAfuera', 'PulgaresAfuera', 'DocumentosALado',
#        'ManoAbierta', 'DocumentosALado', 'DocumentosALado', 'ManoAbierta',
#        'DocumentosALado', 'PulgaresAfuera', 'PulgaresAfuera',
#        'ManoAbierta', 'ManoAbierta', 'PulgaresAfuera', 'ManoAbierta',
#        'ManoAbierta', 'ManoAbierta', 'DocumentosALado', 'ManoAbierta',
#        'DocumentosALado', 'ManoAbierta', 'DocumentosALado', 'ManoAbierta',
#        'PulgaresAfuera', 'PulgaresAfuera', 'DocumentosALado',
#        'DocumentosALado', 'DocumentosALado', 'ManoAbierta',
#        'DocumentosALado', 'PulgaresAfuera', 'DocumentosALado',
#        'ManoAbierta', 'DocumentosALado', 'DocumentosALado',
#        'DocumentosALado', 'DocumentosALado', 'PulgaresAfuera',
#        'ManoAbierta', 'DocumentosALado', 'DocumentosALado',
#        'DocumentosALado', 'ManoAbierta', 'DocumentosALado', 'ManoAbierta'],
#       dtype='<U15')

# %%
# 3.3 Evaluate and Serialize Model
from sklearn.metrics import accuracy_score # Accuracy metrics 
import pickle

# %%
for algo, model in fit_models.items():
    yhat = model.predict(X_test)
    print(algo, accuracy_score(y_test, yhat))
# Out:
# lr 0.9868421052631579
# rc 0.993421052631579
# rf 1.0
# gb 0.993421052631579

# %%
fit_models['rf'].predict(X_test)
# Out:
# array(['ManoAbierta', 'PulgaresAfuera', 'PulgaresAfuera', 'ManoAbierta',
#        'ManoAbierta', 'DocumentosALado', 'DocumentosALado',
#        'DocumentosALado', 'ManoAbierta', 'DocumentosALado',
#        'PulgaresAfuera', 'ManoAbierta', 'PulgaresAfuera', 'ManoAbierta',
#        'PulgaresAfuera', 'ManoAbierta', 'DocumentosALado', 'ManoAbierta',
#        'ManoAbierta', 'DocumentosALado', 'DocumentosALado', 'ManoAbierta',
#        'PulgaresAfuera', 'ManoAbierta', 'DocumentosALado', 'ManoAbierta',
#        'ManoAbierta', 'DocumentosALado', 'PulgaresAfuera',
#        'DocumentosALado', 'ManoAbierta', 'ManoAbierta', 'DocumentosALado',
#        'PulgaresAfuera', 'DocumentosALado', 'PulgaresAfuera',
#        'DocumentosALado', 'DocumentosALado', 'PulgaresAfuera',
#        'PulgaresAfuera', 'PulgaresAfuera', 'ManoAbierta',
#        'DocumentosALado', 'DocumentosALado', 'PulgaresAfuera',
#        'DocumentosALado', 'PulgaresAfuera', 'DocumentosALado',
#        'ManoAbierta', 'DocumentosALado', 'DocumentosALado',
#        'DocumentosALado', 'DocumentosALado', 'DocumentosALado',
#        'PulgaresAfuera', 'ManoAbierta', 'DocumentosALado',
#        'DocumentosALado', 'ManoAbierta', 'PulgaresAfuera', 'ManoAbierta',
#        'DocumentosALado', 'DocumentosALado', 'DocumentosALado',
#        'ManoAbierta', 'DocumentosALado', 'DocumentosALado',
#        'PulgaresAfuera', 'DocumentosALado', 'ManoAbierta',
#        'DocumentosALado', 'PulgaresAfuera', 'DocumentosALado',
#        'ManoAbierta', 'PulgaresAfuera', 'DocumentosALado',
#        'DocumentosALado', 'ManoAbierta', 'DocumentosALado',
#        'DocumentosALado', 'DocumentosALado', 'ManoAbierta',
#        'DocumentosALado', 'PulgaresAfuera', 'DocumentosALado',
#        'DocumentosALado', 'ManoAbierta', 'ManoAbierta', 'ManoAbierta',
#        'ManoAbierta', 'DocumentosALado', 'ManoAbierta', 'DocumentosALado',
#        'DocumentosALado', 'DocumentosALado', 'DocumentosALado',
#        'DocumentosALado', 'DocumentosALado', 'DocumentosALado',
#        'DocumentosALado', 'DocumentosALado', 'DocumentosALado',
#        'PulgaresAfuera', 'PulgaresAfuera', 'PulgaresAfuera',
#        'DocumentosALado', 'DocumentosALado', 'ManoAbierta',
#        'PulgaresAfuera', 'PulgaresAfuera', 'DocumentosALado',
#        'ManoAbierta', 'DocumentosALado', 'DocumentosALado', 'ManoAbierta',
#        'DocumentosALado', 'PulgaresAfuera', 'PulgaresAfuera',
#        'ManoAbierta', 'ManoAbierta', 'PulgaresAfuera', 'ManoAbierta',
#        'ManoAbierta', 'ManoAbierta', 'DocumentosALado', 'ManoAbierta',
#        'DocumentosALado', 'ManoAbierta', 'DocumentosALado', 'ManoAbierta',
#        'PulgaresAfuera', 'PulgaresAfuera', 'DocumentosALado',
#        'DocumentosALado', 'DocumentosALado', 'ManoAbierta',
#        'DocumentosALado', 'PulgaresAfuera', 'DocumentosALado',
#        'ManoAbierta', 'DocumentosALado', 'DocumentosALado',
#        'DocumentosALado', 'DocumentosALado', 'PulgaresAfuera',
#        'ManoAbierta', 'DocumentosALado', 'DocumentosALado',
#        'DocumentosALado', 'ManoAbierta', 'DocumentosALado', 'ManoAbierta'],
#       dtype=object)

# %%
y_test
# Out:
# 64         ManoAbierta
# 401     PulgaresAfuera
# 479     PulgaresAfuera
# 124        ManoAbierta
# 131        ManoAbierta
#             ...
# 323    DocumentosALado
# 194    DocumentosALado
# 108        ManoAbierta
# 312    DocumentosALado
# 99         ManoAbierta
# Name: class, Length: 152, dtype: object

# %%
with open('body_language.pkl', 'wb') as f:
    pickle.dump(fit_models['rf'], f)

# %%
# 4. Make Detections with Model
with open('body_language.pkl', 'rb') as f:
    model = pickle.load(f)

# %%
model
# Out:
# Pipeline(steps=[('standardscaler', StandardScaler()),
#                 ('randomforestclassifier', RandomForestClassifier())])

# %%
cap = cv2.VideoCapture(0)
# Initiate holistic model
with mp_holistic.Holistic(min_detection_confidence=0.5, min_tracking_confidence=0.5) as holistic:
    
    while cap.isOpened():
        ret, frame = cap.read()
        
        # Recolor Feed
        image = cv2.cvtColor(frame, cv2.COLOR_BGR2RGB)
        image.flags.writeable = False        
        
        # Make Detections
        results = holistic.process(image)
        # print(results.face_landmarks)
        
        # face_landmarks, pose_landmarks, left_hand_landmarks, right_hand_landmarks
        
        # Recolor image back to BGR for rendering
        image.flags.writeable = True   
        image = cv2.cvtColor(image, cv2.COLOR_RGB2BGR)
        
        # 1. Draw face landmarks
        mp_drawing.draw_landmarks(image, results.face_landmarks, mp_holistic.FACEMESH_TESSELATION, 
                                 mp_drawing.DrawingSpec(color=(80,110,10), thickness=1, circle_radius=1),
                                 mp_drawing.DrawingSpec(color=(80,256,121), thickness=1, circle_radius=1)
                                 )
        
        # 2. Right hand
        mp_drawing.draw_landmarks(image, results.right_hand_landmarks, mp_holistic.HAND_CONNECTIONS, 
                                 mp_drawing.DrawingSpec(color=(80,22,10), thickness=2, circle_radius=4),
                                 mp_drawing.DrawingSpec(color=(80,44,121), thickness=2, circle_radius=2)
                                 )

        # 3. Left Hand
        mp_drawing.draw_landmarks(image, results.left_hand_landmarks, mp_holistic.HAND_CONNECTIONS, 
                                 mp_drawing.DrawingSpec(color=(121,22,76), thickness=2, circle_radius=4),
                                 mp_drawing.DrawingSpec(color=(121,44,250), thickness=2, circle_radius=2)
                                 )

        # 4. Pose Detections
        mp_drawing.draw_landmarks(image, results.pose_landmarks, mp_holistic.POSE_CONNECTIONS, 
                                 mp_drawing.DrawingSpec(color=(245,117,66), thickness=2, circle_radius=4),
                                 mp_drawing.DrawingSpec(color=(245,66,230), thickness=2, circle_radius=2)
                                 )
        # Export coordinates
        try:
            # Extract Pose landmarks
            pose = results.pose_landmarks.landmark
            pose_row = list(np.array([[landmark.x, landmark.y, landmark.z, landmark.visibility] for landmark in pose]).flatten())
            
            # Extract Face landmarks
            face = results.face_landmarks.landmark
            face_row = list(np.array([[landmark.x, landmark.y, landmark.z, landmark.visibility] for landmark in face]).flatten())
            
            # Concate rows
            row = pose_row+face_row
            
#             # Append class name 
#             row.insert(0, class_name)
            
#             # Export to CSV
#             with open('coords.csv', mode='a', newline='') as f:
#                 csv_writer = csv.writer(f, delimiter=',', quotechar='"', quoting=csv.QUOTE_MINIMAL)
#                 csv_writer.writerow(row) 

            # Make Detections
            X = pd.DataFrame([row])
            body_language_class = model.predict(X)[0]
            body_language_prob = model.predict_proba(X)[0]
            print(body_language_class, body_language_prob)
            
            # Grab ear coords
            coords = tuple(np.multiply(
                            np.array(
                                (results.pose_landmarks.landmark[mp_holistic.PoseLandmark.LEFT_EAR].x, 
                                 results.pose_landmarks.landmark[mp_holistic.PoseLandmark.LEFT_EAR].y))
                        , [640,480]).astype(int))
            
            cv2.rectangle(image, 
                          (coords[0], coords[1]+5), 
                          (coords[0]+len(body_language_class)*20, coords[1]-30), 
                          (245, 117, 16), -1)
            cv2.putText(image, body_language_class, coords, 
                        cv2.FONT_HERSHEY_SIMPLEX, 1, (255, 255, 255), 2, cv2.LINE_AA)
            
            # Get status box
            cv2.rectangle(image, (0,0), (250, 60), (245, 117, 16), -1)
            
            # Display Class
            cv2.putText(image, 'CLASS'
                        , (95,12), cv2.FONT_HERSHEY_SIMPLEX, 0.5, (0, 0, 0), 1, cv2.LINE_AA)
            cv2.putText(image, body_language_class.split(' ')[0]
                        , (90,40), cv2.FONT_HERSHEY_SIMPLEX, 1, (255, 255, 255), 2, cv2.LINE_AA)
            
            # Display Probability
            cv2.putText(image, 'PROB'
                        , (15,12), cv2.FONT_HERSHEY_SIMPLEX, 0.5, (0, 0, 0), 1, cv2.LINE_AA)
            cv2.putText(image, str(round(body_language_prob[np.argmax(body_language_prob)],2))
                        , (10,40), cv2.FONT_HERSHEY_SIMPLEX, 1, (255, 255, 255), 2, cv2.LINE_AA)
            
        except:
            pass
                        
        cv2.imshow('Raw Webcam Feed', image)

        if cv2.waitKey(10) & 0xFF == ord('q'):
            break

cap.release()
cv2.destroyAllWindows()
# Out:
# PulgaresAfuera [0.38 0.12 0.5 ]
# PulgaresAfuera [0.41 0.12 0.47]
# PulgaresAfuera [0.41 0.13 0.46]
# PulgaresAfuera [0.38 0.13 0.49]
# PulgaresAfuera [0.39 0.14 0.47]
# PulgaresAfuera [0.37 0.15 0.48]
# PulgaresAfuera [0.29 0.18 0.53]
# PulgaresAfuera [0.28 0.21 0.51]
# PulgaresAfuera [0.35 0.15 0.5 ]
# DocumentosALado [0.44 0.12 0.44]
# PulgaresAfuera [0.42 0.12 0.46]
# DocumentosALado [0.45 0.11 0.44]
# DocumentosALado [0.45 0.11 0.44]
# DocumentosALado [0.46 0.12 0.42]
# DocumentosALado [0.46 0.11 0.43]
# DocumentosALado [0.5  0.11 0.39]
# DocumentosALado [0.59 0.12 0.29]
# DocumentosALado [0.58 0.12 0.3 ]
# DocumentosALado [0.49 0.08 0.43]
# DocumentosALado [0.48 0.08 0.44]
# DocumentosALado [0.47 0.1  0.43]
# DocumentosALado [0.47 0.1  0.43]
# DocumentosALado [0.45 0.1  0.45]
# DocumentosALado [0.46 0.1  0.44]
# DocumentosALado [0.47 0.1  0.43]
# DocumentosALado [0.48 0.09 0.43]
# DocumentosALado [0.47 0.1  0.43]
# DocumentosALado [0.48 0.09 0.43]
# DocumentosALado [0.47 0.1  0.43]
# DocumentosALado [0.47 0.1  0.43]
# DocumentosALado [0.53 0.13 0.34]
# DocumentosALado [0.49 0.26 0.25]
# DocumentosALado [0.5 0.3 0.2]
# DocumentosALado [0.5 0.3 0.2]
# DocumentosALado [0.61 0.19 0.2 ]
# DocumentosALado [0.64 0.18 0.18]
# DocumentosALado [0.64 0.19 0.17]
# DocumentosALado [0.5  0.18 0.32]
# DocumentosALado [0.52 0.17 0.31]
# DocumentosALado [0.56 0.16 0.28]
# DocumentosALado [0.64 0.17 0.19]
# DocumentosALado [0.63 0.17 0.2 ]
# DocumentosALado [0.69 0.18 0.13]
# DocumentosALado [0.65 0.18 0.17]
# DocumentosALado [0.64 0.17 0.19]
# DocumentosALado [0.62 0.16 0.22]
# DocumentosALado [0.59 0.16 0.25]
# DocumentosALado [0.68 0.18 0.14]
# DocumentosALado [0.55 0.15 0.3 ]
# DocumentosALado [0.67 0.16 0.17]
# DocumentosALado [0.68 0.18 0.14]
# DocumentosALado [0.62 0.17 0.21]
# DocumentosALado [0.53 0.15 0.32]
# DocumentosALado [0.56 0.14 0.3 ]
# DocumentosALado [0.6  0.14 0.26]
# DocumentosALado [0.59 0.17 0.24]
# DocumentosALado [0.64 0.16 0.2 ]
# DocumentosALado [0.58 0.14 0.28]
# DocumentosALado [0.57 0.14 0.29]
# DocumentosALado [0.53 0.13 0.34]
# DocumentosALado [0.45 0.13 0.42]
# DocumentosALado [0.48 0.14 0.38]
# DocumentosALado [0.53 0.15 0.32]
# DocumentosALado [0.52 0.18 0.3 ]
# DocumentosALado [0.59 0.15 0.26]
# DocumentosALado [0.52 0.16 0.32]
# DocumentosALado [0.7  0.18 0.12]
# DocumentosALado [0.73 0.19 0.08]
# DocumentosALado [0.68 0.29 0.03]
# DocumentosALado [0.61 0.34 0.05]
# DocumentosALado [0.74 0.25 0.01]
# DocumentosALado [0.69 0.3  0.01]
# DocumentosALado [0.7  0.29 0.01]
# DocumentosALado [0.71 0.28 0.01]
# DocumentosALado [0.7  0.29 0.01]
# DocumentosALado [0.67 0.31 0.02]
# DocumentosALado [0.67 0.31 0.02]
# DocumentosALado [0.65 0.33 0.02]
# DocumentosALado [0.67 0.31 0.02]
# DocumentosALado [0.61 0.37 0.02]
# DocumentosALado [0.55 0.41 0.04]
# DocumentosALado [0.55 0.41 0.04]
# DocumentosALado [0.55 0.41 0.04]
# DocumentosALado [0.57 0.39 0.04]
# DocumentosALado [0.55 0.41 0.04]
# DocumentosALado [0.55 0.41 0.04]
# DocumentosALado [0.55 0.41 0.04]
# DocumentosALado [0.55 0.41 0.04]
# DocumentosALado [0.55 0.41 0.04]
# DocumentosALado [0.55 0.41 0.04]
# DocumentosALado [0.55 0.41 0.04]
# DocumentosALado [0.55 0.41 0.04]
# DocumentosALado [0.54 0.42 0.04]
# DocumentosALado [0.6  0.34 0.06]
# DocumentosALado [0.92 0.04 0.04]
# DocumentosALado [0.94 0.04 0.02]
# DocumentosALado [0.94 0.04 0.02]
# DocumentosALado [0.95 0.03 0.02]
# DocumentosALado [0.94 0.04 0.02]
# DocumentosALado [0.91 0.07 0.02]
# DocumentosALado [0.88 0.11 0.01]
# DocumentosALado [0.87 0.11 0.02]
# DocumentosALado [0.85 0.14 0.01]
# DocumentosALado [0.85 0.14 0.01]
# DocumentosALado [0.95 0.04 0.01]
# DocumentosALado [0.94 0.05 0.01]
# DocumentosALado [0.95 0.04 0.01]
# DocumentosALado [0.95 0.04 0.01]
# DocumentosALado [0.95 0.04 0.01]
# DocumentosALado [0.94 0.05 0.01]
# DocumentosALado [0.92 0.07 0.01]
# DocumentosALado [0.88 0.11 0.01]
# DocumentosALado [0.86 0.13 0.01]
# DocumentosALado [0.81 0.17 0.02]
# DocumentosALado [0.76 0.21 0.03]
# DocumentosALado [0.71 0.27 0.02]
# DocumentosALado [0.7  0.28 0.02]
# DocumentosALado [0.68 0.28 0.04]
# DocumentosALado [0.64 0.33 0.03]
# DocumentosALado [0.63 0.34 0.03]
# ManoAbierta [0.46 0.47 0.07]
# ManoAbierta [0.43 0.46 0.11]
# DocumentosALado [0.48 0.45 0.07]
# DocumentosALado [0.55 0.37 0.08]
# DocumentosALado [0.54 0.34 0.12]
# DocumentosALado [0.63 0.3  0.07]
# DocumentosALado [0.68 0.25 0.07]
# DocumentosALado [0.73 0.22 0.05]
# DocumentosALado [0.66 0.22 0.12]
# DocumentosALado [0.71 0.24 0.05]
# DocumentosALado [0.69 0.22 0.09]
# DocumentosALado [0.71 0.23 0.06]
# DocumentosALado [0.73 0.22 0.05]
# DocumentosALado [0.78 0.18 0.04]
# DocumentosALado [0.8  0.17 0.03]
# DocumentosALado [0.81 0.16 0.03]
# DocumentosALado [0.79 0.19 0.02]
# DocumentosALado [0.81 0.16 0.03]
# DocumentosALado [0.81 0.16 0.03]
# DocumentosALado [0.81 0.16 0.03]
# DocumentosALado [0.78 0.19 0.03]
# DocumentosALado [0.74 0.23 0.03]
# DocumentosALado [0.73 0.24 0.03]
# DocumentosALado [0.72 0.25 0.03]
# DocumentosALado [0.74 0.24 0.02]
# DocumentosALado [0.72 0.25 0.03]
# DocumentosALado [0.71 0.26 0.03]
# DocumentosALado [0.68 0.29 0.03]
# DocumentosALado [0.66 0.31 0.03]
# DocumentosALado [0.57 0.4  0.03]
# DocumentosALado [0.59 0.39 0.02]
# DocumentosALado [0.57 0.41 0.02]
# DocumentosALado [0.57 0.41 0.02]
# DocumentosALado [0.57 0.41 0.02]
# DocumentosALado [0.57 0.41 0.02]
# DocumentosALado [0.57 0.4  0.03]
# DocumentosALado [0.57 0.41 0.02]
# DocumentosALado [0.57 0.41 0.02]
# DocumentosALado [0.57 0.41 0.02]
# DocumentosALado [0.57 0.41 0.02]
# DocumentosALado [0.57 0.41 0.02]
# DocumentosALado [0.57 0.41 0.02]
# DocumentosALado [0.57 0.4  0.03]
# DocumentosALado [0.57 0.41 0.02]
# DocumentosALado [0.56 0.42 0.02]
# DocumentosALado [0.56 0.42 0.02]
# DocumentosALado [0.55 0.43 0.02]
# DocumentosALado [0.57 0.41 0.02]
# DocumentosALado [0.57 0.41 0.02]
# DocumentosALado [0.57 0.41 0.02]
# DocumentosALado [0.57 0.4  0.03]
# DocumentosALado [0.57 0.41 0.02]
# DocumentosALado [0.57 0.4  0.03]
# DocumentosALado [0.57 0.41 0.02]
# DocumentosALado [0.56 0.42 0.02]
# DocumentosALado [0.55 0.43 0.02]
# DocumentosALado [0.56 0.42 0.02]
# DocumentosALado [0.55 0.43 0.02]
# ManoAbierta [0.4  0.57 0.03]
# DocumentosALado [0.49 0.48 0.03]
# DocumentosALado [0.55 0.43 0.02]
# DocumentosALado [0.55 0.43 0.02]
# DocumentosALado [0.54 0.43 0.03]
# DocumentosALado [0.55 0.43 0.02]
# DocumentosALado [0.53 0.43 0.04]
# DocumentosALado [0.54 0.41 0.05]
# DocumentosALado [0.54 0.41 0.05]
# DocumentosALado [0.54 0.41 0.05]
# DocumentosALado [0.54 0.41 0.05]
# DocumentosALado [0.54 0.42 0.04]
# DocumentosALado [0.54 0.42 0.04]
# DocumentosALado [0.54 0.4  0.06]
# DocumentosALado [0.53 0.41 0.06]
# DocumentosALado [0.52 0.41 0.07]
# DocumentosALado [0.49 0.42 0.09]
# DocumentosALado [0.5  0.43 0.07]
# DocumentosALado [0.52 0.4  0.08]
# DocumentosALado [0.53 0.4  0.07]
# DocumentosALado [0.53 0.41 0.06]
# DocumentosALado [0.54 0.4  0.06]
# DocumentosALado [0.52 0.44 0.04]
# ManoAbierta [0.36 0.59 0.05]
# ManoAbierta [0.32 0.62 0.06]
# ManoAbierta [0.3  0.64 0.06]
# ManoAbierta [0.31 0.63 0.06]
# ManoAbierta [0.33 0.62 0.05]
# ManoAbierta [0.32 0.62 0.06]
# ManoAbierta [0.3  0.64 0.06]
# ManoAbierta [0.29 0.65 0.06]
# ManoAbierta [0.29 0.66 0.05]
# ManoAbierta [0.28 0.67 0.05]
# ManoAbierta [0.31 0.64 0.05]
# ManoAbierta [0.31 0.63 0.06]
# ManoAbierta [0.28 0.67 0.05]
# ManoAbierta [0.29 0.65 0.06]
# ManoAbierta [0.29 0.65 0.06]
# ManoAbierta [0.41 0.48 0.11]
# ManoAbierta [0.4  0.46 0.14]
# ManoAbierta [0.42 0.48 0.1 ]
# ManoAbierta [0.42 0.46 0.12]
# ManoAbierta [0.37 0.56 0.07]
# ManoAbierta [0.38 0.55 0.07]
# ManoAbierta [0.4  0.54 0.06]
# ManoAbierta [0.41 0.52 0.07]
# ManoAbierta [0.41 0.5  0.09]
# ManoAbierta [0.39 0.53 0.08]
# ManoAbierta [0.41 0.5  0.09]
# ManoAbierta [0.4  0.52 0.08]
# ManoAbierta [0.38 0.53 0.09]
# ManoAbierta [0.38 0.53 0.09]
# ManoAbierta [0.37 0.56 0.07]
# ManoAbierta [0.33 0.61 0.06]
# ManoAbierta [0.33 0.6  0.07]
# ManoAbierta [0.3  0.64 0.06]
# ManoAbierta [0.27 0.68 0.05]
# ManoAbierta [0.27 0.69 0.04]
# ManoAbierta [0.26 0.7  0.04]
# ManoAbierta [0.27 0.69 0.04]
# ManoAbierta [0.26 0.7  0.04]
# ManoAbierta [0.26 0.7  0.04]
# ManoAbierta [0.27 0.69 0.04]
# ManoAbierta [0.28 0.68 0.04]
# ManoAbierta [0.26 0.7  0.04]
# ManoAbierta [0.27 0.69 0.04]
# ManoAbierta [0.27 0.69 0.04]
# ManoAbierta [0.27 0.69 0.04]
# ManoAbierta [0.26 0.7  0.04]
# ManoAbierta [0.26 0.7  0.04]
# ManoAbierta [0.26 0.7  0.04]
# ManoAbierta [0.25 0.71 0.04]
# ManoAbierta [0.27 0.69 0.04]
# ManoAbierta [0.27 0.69 0.04]
# ManoAbierta [0.26 0.7  0.04]
# ManoAbierta [0.27 0.69 0.04]
# ManoAbierta [0.26 0.7  0.04]
# ManoAbierta [0.28 0.67 0.05]
# ManoAbierta [0.27 0.68 0.05]
# ManoAbierta [0.26 0.69 0.05]
# ManoAbierta [0.28 0.67 0.05]
# ManoAbierta [0.28 0.67 0.05]
# ManoAbierta [0.28 0.67 0.05]
# ManoAbierta [0.27 0.68 0.05]
# ManoAbierta [0.28 0.68 0.04]
# ManoAbierta [0.28 0.67 0.05]
# ManoAbierta [0.27 0.68 0.05]
# ManoAbierta [0.26 0.69 0.05]
# ManoAbierta [0.27 0.68 0.05]
# ManoAbierta [0.28 0.67 0.05]
# ManoAbierta [0.28 0.67 0.05]
# ManoAbierta [0.28 0.67 0.05]
# ManoAbierta [0.27 0.68 0.05]
# ManoAbierta [0.27 0.68 0.05]
# ManoAbierta [0.27 0.68 0.05]
# ManoAbierta [0.28 0.67 0.05]
# ManoAbierta [0.29 0.65 0.06]
# ManoAbierta [0.28 0.67 0.05]
# ManoAbierta [0.28 0.67 0.05]
# ManoAbierta [0.28 0.66 0.06]
# ManoAbierta [0.28 0.67 0.05]
# ManoAbierta [0.27 0.68 0.05]
# ManoAbierta [0.29 0.66 0.05]
# ManoAbierta [0.29 0.65 0.06]
# ManoAbierta [0.28 0.66 0.06]
# ManoAbierta [0.29 0.66 0.05]
# ManoAbierta [0.29 0.67 0.04]
# ManoAbierta [0.28 0.67 0.05]
# ManoAbierta [0.28 0.67 0.05]
# ManoAbierta [0.28 0.67 0.05]
# ManoAbierta [0.28 0.67 0.05]
# ManoAbierta [0.28 0.67 0.05]
# ManoAbierta [0.28 0.67 0.05]
# ManoAbierta [0.28 0.67 0.05]
# ManoAbierta [0.28 0.67 0.05]
# ManoAbierta [0.28 0.67 0.05]
# ManoAbierta [0.28 0.67 0.05]
# ManoAbierta [0.28 0.67 0.05]
# ManoAbierta [0.28 0.67 0.05]
# ManoAbierta [0.3  0.64 0.06]
# ManoAbierta [0.3  0.66 0.04]
# ManoAbierta [0.3  0.65 0.05]
# DocumentosALado [0.51 0.45 0.04]
# ManoAbierta [0.33 0.62 0.05]
# ManoAbierta [0.33 0.62 0.05]
# ManoAbierta [0.34 0.6  0.06]
# ManoAbierta [0.34 0.6  0.06]
# ManoAbierta [0.36 0.58 0.06]
# ManoAbierta [0.41 0.52 0.07]
# ManoAbierta [0.42 0.46 0.12]
# ManoAbierta [0.42 0.46 0.12]
# ManoAbierta [0.42 0.46 0.12]
# ManoAbierta [0.42 0.46 0.12]
# ManoAbierta [0.41 0.49 0.1 ]
# ManoAbierta [0.42 0.48 0.1 ]
# ManoAbierta [0.38 0.55 0.07]
# ManoAbierta [0.35 0.58 0.07]
# ManoAbierta [0.35 0.58 0.07]
# ManoAbierta [0.34 0.59 0.07]
# ManoAbierta [0.37 0.56 0.07]
# ManoAbierta [0.37 0.56 0.07]
# ManoAbierta [0.34 0.6  0.06]
# ManoAbierta [0.35 0.58 0.07]
# ManoAbierta [0.34 0.6  0.06]
# ManoAbierta [0.31 0.63 0.06]
# ManoAbierta [0.34 0.6  0.06]
# ManoAbierta [0.33 0.61 0.06]
# ManoAbierta [0.33 0.61 0.06]
# ManoAbierta [0.29 0.65 0.06]
# ManoAbierta [0.31 0.63 0.06]
# ManoAbierta [0.31 0.63 0.06]
# ManoAbierta [0.33 0.61 0.06]
# DocumentosALado [0.52 0.39 0.09]
# DocumentosALado [0.5  0.41 0.09]
# DocumentosALado [0.48 0.45 0.07]
# DocumentosALado [0.49 0.45 0.06]
# DocumentosALado [0.58 0.36 0.06]
# DocumentosALado [0.6  0.34 0.06]
# DocumentosALado [0.66 0.29 0.05]
# DocumentosALado [0.7  0.26 0.04]
# DocumentosALado [0.76 0.19 0.05]
# DocumentosALado [0.73 0.21 0.06]
# DocumentosALado [0.71 0.24 0.05]
# DocumentosALado [0.73 0.22 0.05]
# DocumentosALado [0.72 0.25 0.03]
# DocumentosALado [0.74 0.24 0.02]
# DocumentosALado [0.79 0.19 0.02]
# DocumentosALado [0.84 0.14 0.02]
# DocumentosALado [0.93 0.07 0.  ]
# DocumentosALado [0.87 0.13 0.  ]
# DocumentosALado [0.87 0.13 0.  ]
# DocumentosALado [0.5  0.49 0.01]
# DocumentosALado [0.52 0.46 0.02]
# DocumentosALado [0.57 0.38 0.05]
# DocumentosALado [0.52 0.38 0.1 ]
# DocumentosALado [0.73 0.21 0.06]
# DocumentosALado [0.79 0.18 0.03]
# DocumentosALado [0.84 0.13 0.03]
# DocumentosALado [0.84 0.11 0.05]
# DocumentosALado [0.83 0.13 0.04]
# DocumentosALado [0.88 0.08 0.04]
# DocumentosALado [0.88 0.09 0.03]
# DocumentosALado [0.84 0.12 0.04]
# DocumentosALado [0.82 0.14 0.04]
# DocumentosALado [0.82 0.15 0.03]
# DocumentosALado [0.77 0.2  0.03]
# DocumentosALado [0.78 0.2  0.02]
# DocumentosALado [0.88 0.08 0.04]
# DocumentosALado [0.89 0.08 0.03]
# DocumentosALado [0.85 0.13 0.02]
# DocumentosALado [0.87 0.1  0.03]
# DocumentosALado [0.87 0.11 0.02]
# DocumentosALado [0.88 0.08 0.04]
# DocumentosALado [0.86 0.12 0.02]
# DocumentosALado [0.85 0.11 0.04]
# DocumentosALado [0.84 0.13 0.03]
# DocumentosALado [0.83 0.13 0.04]
# DocumentosALado [0.82 0.15 0.03]
# DocumentosALado [0.81 0.16 0.03]
# DocumentosALado [0.75 0.2  0.05]
# DocumentosALado [0.76 0.2  0.04]
# DocumentosALado [0.76 0.2  0.04]
# DocumentosALado [0.75 0.19 0.06]
# DocumentosALado [0.77 0.18 0.05]
# DocumentosALado [0.77 0.18 0.05]
# DocumentosALado [0.75 0.2  0.05]
# DocumentosALado [0.7  0.21 0.09]
# DocumentosALado [0.7  0.23 0.07]
# DocumentosALado [0.65 0.28 0.07]
# DocumentosALado [0.64 0.28 0.08]
# DocumentosALado [0.62 0.31 0.07]
# DocumentosALado [0.62 0.3  0.08]
# DocumentosALado [0.61 0.32 0.07]
# DocumentosALado [0.57 0.35 0.08]
# DocumentosALado [0.58 0.29 0.13]
# DocumentosALado [0.63 0.3  0.07]
# DocumentosALado [0.66 0.27 0.07]
# DocumentosALado [0.73 0.21 0.06]
# DocumentosALado [0.83 0.12 0.05]
# DocumentosALado [0.84 0.11 0.05]
# DocumentosALado [0.85 0.11 0.04]
# DocumentosALado [0.86 0.1  0.04]
# DocumentosALado [0.83 0.13 0.04]
# DocumentosALado [0.84 0.12 0.04]
# DocumentosALado [0.83 0.12 0.05]
# DocumentosALado [0.83 0.13 0.04]
# DocumentosALado [0.86 0.11 0.03]
# DocumentosALado [0.94 0.05 0.01]
# DocumentosALado [0.92 0.07 0.01]
# DocumentosALado [0.92 0.07 0.01]
# DocumentosALado [0.91 0.08 0.01]
# DocumentosALado [0.88 0.12 0.  ]
# DocumentosALado [0.8 0.2 0. ]
# DocumentosALado [0.76 0.24 0.  ]
# DocumentosALado [0.57 0.42 0.01]
# DocumentosALado [0.56 0.43 0.01]
# DocumentosALado [0.6  0.38 0.02]
# DocumentosALado [0.55 0.44 0.01]
# DocumentosALado [0.57 0.41 0.02]
# DocumentosALado [0.66 0.34 0.  ]
# DocumentosALado [0.59 0.39 0.02]
# DocumentosALado [0.52 0.46 0.02]
# DocumentosALado [0.54 0.44 0.02]
# DocumentosALado [0.51 0.46 0.03]
# DocumentosALado [0.5  0.48 0.02]
# DocumentosALado [0.51 0.47 0.02]
# DocumentosALado [0.5  0.48 0.02]
# DocumentosALado [0.5  0.48 0.02]
# DocumentosALado [0.5  0.48 0.02]
# DocumentosALado [0.49 0.48 0.03]
# DocumentosALado [0.49 0.48 0.03]
# DocumentosALado [0.49 0.49 0.02]
# ManoAbierta [0.47 0.51 0.02]
# ManoAbierta [0.44 0.54 0.02]
# ManoAbierta [0.42 0.56 0.02]
# ManoAbierta [0.39 0.56 0.05]
# ManoAbierta [0.37 0.56 0.07]
# ManoAbierta [0.36 0.57 0.07]
# ManoAbierta [0.36 0.59 0.05]
# ManoAbierta [0.47 0.52 0.01]
# ManoAbierta [0.48 0.5  0.02]
# ManoAbierta [0.48 0.5  0.02]
# DocumentosALado [0.54 0.44 0.02]
# DocumentosALado [0.48 0.35 0.17]
# DocumentosALado [0.37 0.33 0.3 ]
# ManoAbierta [0.35 0.36 0.29]
# DocumentosALado [0.42 0.35 0.23]
# DocumentosALado [0.45 0.35 0.2 ]
# DocumentosALado [0.53 0.4  0.07]
# DocumentosALado [0.5  0.48 0.02]
# DocumentosALado [0.49 0.48 0.03]
# ManoAbierta [0.45 0.51 0.04]
# ManoAbierta [0.38 0.59 0.03]
# ManoAbierta [0.37 0.6  0.03]
# ManoAbierta [0.34 0.61 0.05]
# ManoAbierta [0.35 0.6  0.05]
# ManoAbierta [0.33 0.61 0.06]
# ManoAbierta [0.32 0.64 0.04]
# ManoAbierta [0.29 0.68 0.03]
# ManoAbierta [0.3  0.68 0.02]
# ManoAbierta [0.21 0.79 0.  ]
# ManoAbierta [0.2 0.8 0. ]
# ManoAbierta [0.2  0.79 0.01]
# ManoAbierta [0.18 0.81 0.01]
# ManoAbierta [0.21 0.78 0.01]
# ManoAbierta [0.19 0.79 0.02]
# ManoAbierta [0.18 0.8  0.02]
# ManoAbierta [0.19 0.78 0.03]
# ManoAbierta [0.2  0.76 0.04]
# ManoAbierta [0.21 0.75 0.04]
# ManoAbierta [0.21 0.76 0.03]
# ManoAbierta [0.21 0.75 0.04]
# ManoAbierta [0.2  0.77 0.03]
# ManoAbierta [0.22 0.74 0.04]
# ManoAbierta [0.23 0.74 0.03]
# ManoAbierta [0.14 0.83 0.03]
# ManoAbierta [0.17 0.79 0.04]
# ManoAbierta [0.18 0.78 0.04]
# ManoAbierta [0.19 0.77 0.04]
# ManoAbierta [0.25 0.71 0.04]
# ManoAbierta [0.28 0.68 0.04]
# ManoAbierta [0.28 0.68 0.04]
# ManoAbierta [0.28 0.68 0.04]
# ManoAbierta [0.3  0.66 0.04]
# ManoAbierta [0.3  0.66 0.04]
# ManoAbierta [0.3  0.66 0.04]
# ManoAbierta [0.3  0.66 0.04]
# ManoAbierta [0.2  0.78 0.02]
# ManoAbierta [0.09 0.9  0.01]
# ManoAbierta [0.08 0.91 0.01]
# ManoAbierta [0.08 0.91 0.01]
# ManoAbierta [0.08 0.92 0.  ]
# ManoAbierta [0.18 0.8  0.02]
# ManoAbierta [0.35 0.6  0.05]
# ManoAbierta [0.39 0.54 0.07]
# ManoAbierta [0.44 0.49 0.07]
# DocumentosALado [0.56 0.38 0.06]
# DocumentosALado [0.6  0.33 0.07]
# DocumentosALado [0.66 0.25 0.09]
# DocumentosALado [0.65 0.21 0.14]
# DocumentosALado [0.7  0.15 0.15]
# DocumentosALado [0.7  0.16 0.14]
# DocumentosALado [0.72 0.14 0.14]
# DocumentosALado [0.77 0.13 0.1 ]
# DocumentosALado [0.75 0.12 0.13]
# DocumentosALado [0.78 0.1  0.12]
# DocumentosALado [0.75 0.09 0.16]
# DocumentosALado [0.77 0.1  0.13]
# DocumentosALado [0.82 0.09 0.09]
# DocumentosALado [0.72 0.18 0.1 ]
# DocumentosALado [0.65 0.22 0.13]
# DocumentosALado [0.66 0.23 0.11]
# DocumentosALado [0.62 0.25 0.13]
# DocumentosALado [0.62 0.26 0.12]
# DocumentosALado [0.68 0.24 0.08]
# DocumentosALado [0.77 0.12 0.11]

# %%
tuple(np.multiply(np.array((results.pose_landmarks.landmark[mp_holistic.PoseLandmark.LEFT_EAR].x, 
results.pose_landmarks.landmark[mp_holistic.PoseLandmark.LEFT_EAR].y)), [640,480]).astype(int))
# Out:
# (368, 228)
